# %% [markdown]
# # Atividade: Construindo um relatório com IA
#
# Nesta segunda parte da aula, você vai usar uma inteligência artificial (Claude, ChatGPT ou Gemini) para aprofundar a análise que fizemos no notebook. Ao final, você terá um relatório completo, montado neste próprio notebook, em células de texto.
#
# **Antes de começar:**
#
# 1. Abra uma conta gratuita em claude.ai, chat.openai.com ou gemini.google.com
# 2. Envie o arquivo `student_habits_performance.csv` no chat da IA
# 3. Neste notebook, crie uma célula de texto com o título: **Relatório de Análise — Hábitos e Desempenho dos Alunos**
#
# > **Observação importante:** esta base é fictícia, pode enviar sem problemas. No trabalho real, nunca envie dados de pessoas reais para uma IA pública.
#
# ---
#
# ## Parte 1
#
# Faça as três perguntas abaixo, na ordem, para a mesma IA. Observe como a resposta melhora a cada versão.
#
# **Pergunta 1 (apenas a pergunta):**
#
# ```
# Qual hábito mais influencia a nota dos alunos?
# ```
#
# **Pergunta 2 (a pergunta com contexto):**
#
# ```
# Esta base tem 1000 alunos, com hábitos (horas de estudo, sono, redes sociais, exercício) e a nota final no exame (exam_score). Analise quais hábitos mais influenciam a nota e mostre os números que comprovam.
# ```
#
# **Pergunta 3 (contexto, persona e formato de resposta):**
#
# ```
# Você é um analista de dados educacionais experiente. Esta base tem 1000 alunos, com hábitos e a nota final (exam_score). Identifique os 3 hábitos que mais impactam a nota, apresente cada um com o número que comprova e escreva em linguagem clara para a direção de uma escola.
# ```
#
# No relatório, crie a seção **"1. Engenharia de Prompt"** e responda: o que mudou da primeira para a terceira resposta? Qual delas você usaria num trabalho real? Cole a melhor das três respostas.
#
# ---
#
# ## Parte 2
#
# O heatmap que fizemos usou apenas as colunas numéricas. A base também tem colunas de texto que o código não analisou. Use o estilo da Pergunta 3 (com contexto e persona) para investigar pelo menos três das perguntas abaixo:
#
# ```
# A qualidade da dieta do aluno (diet_quality) faz diferença na nota? Mostre a média por grupo.
# ```
#
# ```
# Alunos com trabalho de meio período (part_time_job) vão pior nas notas?
# ```
#
# ```
# A escolaridade dos pais (parental_education_level) tem relação com o desempenho?
# ```
#
# ```
# Existe uma quantidade ideal de horas de sono para tirar as melhores notas?
# ```
#
# No relatório, crie a seção **"2. Novas análises"** e cole os insights que achou mais interessantes.
#
# **Atenção:** alguns desses fatores quase não mudam a nota. Isso também é uma descoberta, pois mostra que nem tudo que imaginamos ser importante realmente é.
#
# ---
#
# ## Parte 3
#
# Faça a seguinte pergunta para a IA:
#
# ```
# Por que os alunos mais velhos desta base tiraram notas muito mais altas?
# ```
#
# Agora confira no notebook: a idade tem relação com a nota? Observe como a IA respondeu. Ela inventou uma explicação ou avisou que não havia relação nos dados?
#
# No relatório, crie a seção **"3. Cuidados e Ética no uso da IA"** e escreva, com suas palavras, o que aconteceu e por que é perigoso confiar cegamente na IA no trabalho.
#
# Antes de finalizar, confira um dos números que a IA forneceu em qualquer uma das partes, usando o seu notebook. Um bom analista sempre confere.
#
# ---
#
# ## Entrega
#
# Ao final, seu notebook deve conter as células de código feitas em aula e as três seções do relatório em Markdown:
#
# - Relatório de Análise — Hábitos e Desempenho dos Alunos
# - 1. Engenharia de Prompt
# - 2. Novas análises
# - 3. Cuidados e Ética no uso da IA
#
# Salve e envie pelo Classroom.

# %% [markdown]
# **1. Qual hábito mais influencia a nota dos alunos?**
#
# Analisando o arquivo, o hábito que **mais influencia a nota** é o **tempo de estudo por dia (`study_hours_per_day`)**.
#
# Pelas correlações com a variável `exam_score` (nota da prova):
#
# | Hábito/Fator                | Correlação com a nota |
# | --------------------------- | --------------------: |
# | **Horas de estudo por dia** |             **0,825** |
# | Saúde mental                |                 0,322 |
# | Frequência de exercícios    |                 0,160 |
# | Horas de sono               |                 0,122 |
# | Frequência às aulas         |                 0,090 |
# | Horas em redes sociais      |                -0,167 |
# | Horas assistindo Netflix    |                -0,172 |
#
# ### Interpretação
#
# * **Horas de estudo** possuem uma correlação **muito forte e positiva (0,825)**. Isso significa que, neste conjunto de dados, alunos que estudam mais horas por dia tendem a obter notas significativamente maiores.
# * **Redes sociais** e **Netflix** apresentam correlação negativa: quanto mais tempo gasto nessas atividades, menor tende a ser a nota.
# * Outros fatores, como sono, exercícios e saúde mental, também ajudam, mas têm influência bem menor do que o tempo de estudo.
#
# ### Conclusão
#
# O hábito que mais influencia a nota dos alunos neste dataset é **estudar mais horas por dia**. Entre os hábitos analisados, ele é o fator que apresenta a relação mais forte com o desempenho nas provas.

# %% [markdown]
# **2. Esta base tem 1000 alunos, com hábitos (horas de estudo, sono, redes sociais, exercício) e a nota final no exame (exam_score). Analise quais hábitos mais influenciam a nota e mostre os números que comprovam.**
#
# Analisando a base com **1.000 alunos**, calculei a correlação entre cada hábito e a variável **`exam_score`** (nota final). A correlação varia de **-1 a +1**:
#
# * **Próximo de +1:** forte relação positiva (quando o hábito aumenta, a nota tende a aumentar).
# * **Próximo de -1:** forte relação negativa (quando o hábito aumenta, a nota tende a diminuir).
# * **Próximo de 0:** pouca ou nenhuma relação.
#
# ### Resultados
#
# | Hábito/Fator                | Correlação com a nota (`exam_score`) | Interpretação                     |
# | --------------------------- | -----------------------------------: | --------------------------------- |
# | **Horas de estudo por dia** |                            **0,825** | Influência muito forte e positiva |
# | Saúde mental                |                                0,322 | Influência moderada e positiva    |
# | Horas assistindo Netflix    |                               -0,172 | Influência fraca e negativa       |
# | Horas em redes sociais      |                               -0,167 | Influência fraca e negativa       |
# | Frequência de exercícios    |                                0,160 | Influência fraca e positiva       |
# | Horas de sono               |                                0,122 | Influência fraca e positiva       |
# | Frequência às aulas         |                                0,090 | Influência muito fraca e positiva |
# | Idade                       |                               -0,009 | Praticamente nenhuma influência   |
#
# ### O que os números mostram
#
# * **Horas de estudo por dia (0,825)** são, de longe, o fator mais relacionado ao desempenho. É uma correlação forte, indicando que estudantes que dedicam mais tempo aos estudos tendem a obter notas significativamente maiores.
# * **Saúde mental (0,322)** aparece como o segundo fator mais importante, mostrando uma relação positiva moderada com o desempenho.
# * **Redes sociais (-0,167)** e **Netflix (-0,172)** apresentam correlações negativas, sugerindo que quanto maior o tempo gasto nessas atividades, menor tende a ser a nota.
# * **Exercícios físicos (0,160)** e **sono (0,122)** possuem relação positiva, mas seu efeito é bem menor que o das horas de estudo.
# * **Frequência às aulas (0,090)** apresenta uma relação positiva muito fraca nesta base.
#
# ### Conclusão
#
# Os dados indicam que o hábito que **mais influencia a nota final** é **o tempo de estudo diário**, com uma correlação de **0,825**, muito superior à dos demais fatores. Em seguida aparece a **saúde mental (0,322)**. Já **redes sociais** e **Netflix** estão associadas a uma pequena redução no desempenho, enquanto **sono**, **exercícios** e **frequência às aulas** apresentam influência positiva, porém relativamente fraca. Esses números mostram que, nesta base de 1.000 alunos, **estudar regularmente é o fator mais importante para alcançar notas mais altas**.

# %% [markdown]
# **3. Você é um analista de dados educacionais experiente. Esta base tem 1000 alunos, com hábitos e a nota final (exam_score). Identifique os 3 hábitos que mais impactam a nota, apresente cada um com o número que comprova e escreva em linguagem clara para a direção de uma escola.**
#
# Após analisar a base com **1.000 alunos**, os dados mostram que os **três hábitos com maior impacto na nota final (`exam_score`)** são:
#
# | Posição | Hábito                       | Número que comprova (correlação com `exam_score`) | Interpretação                                                                                                                               |
# | ------: | ---------------------------- | :-----------------------------------------------: | ------------------------------------------------------------------------------------------------------------------------------------------- |
# |  **1º** | **Horas de estudo por dia**  |                     **0,825**                     | É o fator mais importante. Quanto mais tempo o aluno dedica aos estudos, maiores tendem a ser suas notas. A relação é forte e consistente.  |
# |  **2º** | **Saúde mental**             |                     **0,322**                     | Alunos com melhor avaliação de saúde mental tendem a apresentar desempenho superior. A influência é moderada e positiva.                    |
# |  **3º** | **Horas assistindo Netflix** |                     **-0,172**                    | Quanto maior o tempo gasto assistindo Netflix, menor tende a ser a nota. A relação é negativa, embora mais fraca do que as duas anteriores. |
#
# ### Resumo para a direção da escola
#
# A análise dos dados indica que o **tempo de estudo diário** é, de longe, o fator que mais influencia o desempenho dos alunos, apresentando uma **correlação de 0,825** com a nota final. Em segundo lugar, a **saúde mental** também exerce influência importante (**0,322**), sugerindo que ações de apoio ao bem-estar dos estudantes podem contribuir para melhores resultados acadêmicos. Por fim, o **tempo gasto assistindo Netflix** apresenta uma **correlação negativa de -0,172**, indicando que dedicar muitas horas a essa atividade está associado a um desempenho um pouco menor.
#
# Esses resultados sugerem que a escola pode obter melhores resultados ao incentivar **rotinas de estudo consistentes**, fortalecer **programas de apoio à saúde mental** e orientar os alunos sobre o **equilíbrio no uso do tempo para entretenimento**.

# %% [markdown]
# **4. Você é um analista de dados educacionais experiente. Esta base tem 1000 alunos, com hábitos e a nota final (exam_score). Identifique os 3 hábitos que mais impactam a nota, apresente cada um com o número que comprova e escreva em linguagem clara para a direção de uma escola.**
#
# **Relatório para a Direção da Escola – Análise dos Hábitos que Mais Impactam o Desempenho Acadêmico**
#
# Após analisar a base de dados com **1.000 alunos**, foi avaliada a relação entre os hábitos dos estudantes e a nota final (**`exam_score`**) por meio do coeficiente de correlação. Quanto mais próximo de **1**, maior a influência positiva; quanto mais próximo de **-1**, maior a influência negativa.
#
# ### Os 3 hábitos que mais impactam a nota
#
# | Posição | Hábito                       | Número que comprova | O que significa                                                                                                         |
# | ------- | ---------------------------- | ------------------: | ----------------------------------------------------------------------------------------------------------------------- |
# | **1º**  | **Horas de estudo por dia**  |           **0,825** | É o hábito com maior impacto. Alunos que estudam mais horas por dia tendem a obter notas significativamente mais altas. |
# | **2º**  | **Saúde mental**             |           **0,322** | Alunos com melhores indicadores de saúde mental apresentam, em média, melhor desempenho escolar.                        |
# | **3º**  | **Tempo assistindo Netflix** |          **-0,172** | Quanto maior o tempo dedicado ao entretenimento nessa plataforma, menor tende a ser a nota final.                       |
#
# ### Conclusão para a direção
#
# Os resultados mostram que o fator mais importante para o desempenho dos alunos é o **tempo dedicado aos estudos**, com uma correlação de **0,825**, muito superior aos demais hábitos analisados. Em seguida, a **saúde mental** também exerce influência relevante (**0,322**), indicando que ações de acolhimento e apoio emocional podem contribuir para melhores resultados acadêmicos. Por outro lado, o **tempo gasto assistindo Netflix** apresenta uma **correlação negativa (-0,172)**, sugerindo que o excesso de entretenimento está associado a uma pequena redução no desempenho.
#
# ### Recomendações
#
# * Incentivar uma rotina diária de estudos, pois este é o fator de maior impacto no desempenho.
# * Fortalecer programas de apoio à saúde mental e ao bem-estar dos estudantes.
# * Orientar alunos e famílias sobre o uso equilibrado do tempo destinado ao entretenimento, evitando excessos que possam prejudicar os estudos.
#
# Em resumo, os dados indicam que **estudar regularmente**, **cuidar da saúde mental** e **equilibrar o tempo de lazer** são as ações com maior potencial para melhorar o desempenho acadêmico dos alunos.

# %% [markdown]
# **5. A qualidade da dieta do aluno (diet_quality) faz diferença na nota? Mostre a média por grupo.**
#
# Sim. Ao agrupar os **1.000 alunos** pela variável **`diet_quality`** (qualidade da dieta), as médias da nota final (**`exam_score`**) foram:
#
# | Qualidade da dieta | Média da nota (`exam_score`) |
# | ------------------ | ---------------------------: |
# | **Fair (Regular)** |                    **70,43** |
# | **Good (Boa)**     |                    **69,37** |
# | **Poor (Ruim)**    |                    **68,13** |
#
# ### Interpretação
#
# * Alunos com dieta **Regular (Fair)** obtiveram a maior média: **70,43**.
# * Alunos com dieta **Boa (Good)** tiveram média de **69,37**.
# * Alunos com dieta **Ruim (Poor)** apresentaram a menor média: **68,13**.
#
# ### Conclusão
#
# Nesta base de dados, a qualidade da dieta **parece ter uma influência pequena** sobre a nota final. A diferença entre a maior e a menor média é de aproximadamente **2,30 pontos** (70,43 − 68,13). Embora alunos com dieta **Poor** tenham o menor desempenho médio, o fato de o grupo **Fair** superar o grupo **Good** indica que **não há uma relação linear clara** entre a qualidade da dieta e a nota apenas com essas médias. Para afirmar se essa diferença é estatisticamente significativa, seria necessário aplicar um teste estatístico, como uma **ANOVA**.

# %% [markdown]
# **6. Alunos com trabalho de meio período (part_time_job) vão pior nas notas?**
#
# Sim, mas a diferença é **pequena**.
#
# Ao comparar a média da nota final (**`exam_score`**) entre os grupos de alunos com e sem trabalho de meio período (**`part_time_job`**), obtém-se:
#
# | Trabalho de meio período | Média da nota (`exam_score`) |
# | ------------------------ | ---------------------------: |
# | **Não**                  |                    **69,81** |
# | **Sim**                  |                    **68,99** |
#
# ### Diferença
#
# * Alunos **sem trabalho de meio período**: **69,81**
# * Alunos **com trabalho de meio período**: **68,99**
#
# **Diferença:** **0,82 ponto** a favor dos alunos que **não trabalham**.
#
# ### Conclusão
#
# Nesta base de 1.000 alunos, estudantes com trabalho de meio período apresentam, em média, notas **ligeiramente menores** do que aqueles que não trabalham. No entanto, a diferença é de apenas **0,82 ponto**, o que indica um efeito relativamente pequeno.
#
# Para afirmar se essa diferença é realmente significativa (e não apenas resultado da variabilidade da amostra), seria necessário aplicar um teste estatístico, como o **teste t para duas amostras independentes**. Apenas com as médias, conclui-se que existe uma **pequena associação** entre trabalhar meio período e obter notas um pouco menores.

# %% [markdown]
# **7. A escolaridade dos pais (parental_education_level) tem relação com o desempenho?**
#
# Sim, é possível observar uma diferença nas médias das notas conforme a **escolaridade dos pais (`parental_education_level`)**, embora a relação não seja crescente.
#
# | Escolaridade dos pais          | Média da nota (`exam_score`) |
# | ------------------------------ | ---------------------------: |
# | **Bachelor (Graduação)**       |                    **70,27** |
# | **High School (Ensino Médio)** |                    **69,55** |
# | **Master (Mestrado)**          |                    **68,09** |
#
# ### Interpretação
#
# * Alunos cujos pais possuem **graduação (Bachelor)** obtiveram a **maior média**: **70,27**.
# * Alunos cujos pais concluíram o **Ensino Médio (High School)** tiveram média de **69,55**.
# * Alunos cujos pais possuem **mestrado (Master)** apresentaram a **menor média**: **68,09**.
#
# ### Conclusão
#
# Nesta base de dados, **não há evidência de uma relação direta** entre maior escolaridade dos pais e melhor desempenho dos alunos. Se essa relação existisse, seria esperado que a média aumentasse conforme o nível de escolaridade dos pais, mas isso **não ocorre**: o grupo **Bachelor** apresenta a maior média, enquanto o grupo **Master** apresenta a menor.
#
# Portanto, com base nesses dados, a **escolaridade dos pais, isoladamente, não parece ser um bom preditor do desempenho acadêmico**. Para verificar se essas diferenças são estatisticamente significativas, seria recomendável realizar um teste como uma **ANOVA**.

# %% [markdown]
# **8. Existe uma quantidade ideal de horas de sono para tirar as melhores notas?**
#
# Sim. Ao agrupar os alunos por **faixas de horas de sono**, observa-se que existe uma faixa associada às **maiores médias de nota**.
#
# | Horas de sono por noite | Média da nota (`exam_score`) |
# | ----------------------- | ---------------------------: |
# | Menos de 5 horas        |                    **65,01** |
# | 5 a 6 horas             |                    **68,74** |
# | 6 a 7 horas             |                    **69,07** |
# | **7 a 8 horas**         |                    **72,97** |
# | 8 a 9 horas             |                    **69,84** |
# | 9 horas ou mais         |                    **72,81** |
#
# ### Interpretação
#
# * A **maior média** foi observada entre alunos que dormem **7 a 8 horas por noite**, com **72,97 pontos**.
# * Alunos que dormem **9 horas ou mais** também apresentam uma média elevada (**72,81 pontos**), muito próxima da melhor.
# * O pior desempenho ocorre entre os alunos que dormem **menos de 5 horas**, com média de **65,01 pontos**.
#
# ### Conclusão
#
# Os dados sugerem que **dormir cerca de 7 a 8 horas por noite está associado ao melhor desempenho acadêmico** nesta base. Dormir muito pouco está relacionado a notas significativamente menores, enquanto dormir entre **7 e 9 horas** está associado às maiores médias de desempenho. Vale lembrar que essa análise mostra uma **associação**, e não prova que a quantidade de sono seja a causa direta das diferenças nas notas.

# %% [markdown]
# **9. Por que os alunos mais velhos desta base tiraram notas muito mais altas?**
#
# A resposta mais importante é que **não podemos concluir que a idade seja a causa das notas mais altas** apenas olhando essa base.
#
# Se os alunos mais velhos realmente apresentam notas maiores, há algumas explicações possíveis:
#
# 1. **A idade pode estar associada a outros hábitos positivos.**
#
#    * Os alunos mais velhos podem estudar mais horas por dia.
#    * Podem ter melhor frequência às aulas.
#    * Podem administrar melhor o tempo e as responsabilidades.
#
# 2. **O efeito da idade pode ser indireto.**
#
#    * Na análise anterior, a variável **idade** apresentou correlação de aproximadamente **-0,009** com a nota, ou seja, **praticamente nenhuma relação linear**. Isso indica que a idade, sozinha, não explica o desempenho.
#
# 3. **Outras variáveis têm impacto muito maior.**
#    Os dados mostram que os fatores mais relacionados à nota são:
#
#    * **Horas de estudo por dia:** **0,825** (forte relação positiva);
#    * **Saúde mental:** **0,322**;
#    * **Horas de Netflix:** **-0,172**;
#    * **Horas em redes sociais:** **-0,167**.
#
# ### Conclusão
#
# Se em algum agrupamento parece que os alunos mais velhos tiram notas muito maiores, isso provavelmente ocorre porque **eles também apresentam hábitos diferentes**, especialmente **mais horas de estudo**, e não porque a idade, por si só, aumenta a nota.
#
# Para confirmar essa hipótese, o ideal seria fazer uma **análise multivariada** (como uma regressão linear múltipla), que permite medir o efeito da idade **controlando** os demais fatores (estudo, sono, saúde mental, redes sociais etc.). Assim, seria possível verificar se a idade ainda exerce influência depois de considerar esses hábitos.
